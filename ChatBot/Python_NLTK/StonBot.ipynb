# %%
#pip install nltk
#nltk.download()
import nltk

# %%
import nltk
from nltk.chat.util import Chat, reflections

# %%
reflections

{'i am': 'you are',
 'i was': 'you were',
 'i': 'you',
 "i'm": 'you are',
 "i'd": 'you would',
 "i've": 'you have',
 "i'll": 'you will',
 'my': 'your',
 'you are': 'I am',
 'you were': 'I was',
 "you've": 'I have',
 "you'll": 'I will',
 'your': 'my',
 'yours': 'mine',
 'you': 'me',
 'me': 'you'}
# Out:
# {'i am': 'you are',
#  'i was': 'you were',
#  'i': 'you',
#  "i'm": 'you are',
#  "i'd": 'you would',
#  "i've": 'you have',
#  "i'll": 'you will',
#  'my': 'your',
#  'you are': 'I am',
#  'you were': 'I was',
#  "you've": 'I have',
#  "you'll": 'I will',
#  'your': 'my',
#  'yours': 'mine',
#  'you': 'me',
#  'me': 'you'}

# %%
reflections_pt = {'eu': 'você',
                  'eu sou': 'você é',
                  'eu era': 'você era',
                  "eu iria": 'você iria',
                  "eu irei": 'você irá',
                  'meu': 'seu',
                  'você': 'eu',
                  'você é': 'eu sou',
                  'você era': 'eu era',
                  "você irá": 'eu irei',
                  'seu': 'meu'}

# %%
pares = [
    [
     r'Olá tudo bem Eu gostaria de deixar aqui no e-mail o meu currículo para futuras vagas na companhia Este é o melhor caminho?',
     ['Oi tudo bem por ai?Se você quiser se inscrever em qualquer vaga da companhia, você tem um site específico para isso.Nós não aceitamos curriculo por aqui']
    ],
    [
     r'gostaria de saber qual o salário atual para vaga de Green Angel na companhia?',
     ['Olá nós não abrimos salário sem antes conversar com a pessoa pois baseamos isso na experiência de cada um em particular']
    ],  
    [
     r' eu queria saber se na companhia existe uma cultura muito forte e que é respeitado por todas as pessoas que ali trabalham?',
     ['Oi aqui na companhia nós temos uma cultura muito forte e todas as pessoas que são colaboradoras seguem essa cultura muito a risca.É bem legal esse costume nosso.']
    ], 
    [
     r'Eu queria saber a quantidade de colaboradores que vocês tem hoje?',
     ['Hoje a nossa quantidade de colaboradores é bem alta em relação ao número que nós começamos a 5 anos atrás ela mais do que triplicou nesse período de tempo']
    ],  
    [
     r'Na área de pessoas é possível trabalhar com people Analytics ou essa área seria exclusiva para colaboradores que sabem programação?',
     ['people Analytics é uma área em que só se trabalha quando você entende de dados mas não necessariamente você precisa saber sobre programação']
    ], 
    [
     r'A conta Stone é um benefício gratuito ou ele é pago para os clientes que hoje já tem a maquininha?',
     [' Você não necessariamente precisa ter a maquininha para ter uma conta Stone.  ela é liberada para qualquer pessoa física ou jurídica que quiser ter']
    ], 
     [
     r' Qual a maior vantagem de Ser Stone atualmente dado que temos vários competidores atuando no mercado de maquininhas?',
     ['A maior vantagem em ser Stone é justamente o atendimento E A atenção que Damos Para os nossos clientes, esse é o nosso maior diferencial']
    ],     
     [
     r'Ouvi falar que o Recruta é o maior processo seletivo do Brasil.  isso é verdade ou não?',
     [' Hoje o Recruta é um dos maiores do Brasil e um dos melhores no quesito de qualidade.  a sua fonte está totalmente certa em relação a essa informação']
    ],     
     [
     r'vocês aceitam jovem aprendiz de qualquer curso ou precisa ter alguma formação específica para trabalhar na Stone?',
     [' Nós aceitamos pessoas que trabalham bem e tem vontade de aprender e não necessariamente você deve ter alguma formação específica para trabalhar aqui']
    ],     
      [
     r'vocês aceitam pessoas que foram formadas em engenharia da computação para trabalhar na área de pessoas?',
     [' engenharia da computação é uma área um pouco mais específica, mas  caso a pessoa tem habilidade necessária não existe nenhum empecilho']
    ],     
    [
     r'É verdade que você tinha uma ferramenta de conciliação bancária onde facilitava muito a vida do lojista no dia a dia?',
     ['Sim!  o raio x é uma ferramenta de conciliação bancária que realmente deixa a vida deles muito mais fácil e muito mais controlados sem a necessidade de ficar fazendo planilhas para controle de taxa e outros dados']
    ],     
    [
     r'Quantos %  é a taxa da maquininha da Ton?',
     ['O %  da maquininha da Ton  quem poderá te responder melhor será o suporte da Ton!  aqui não é o melhor lugar para você saber essa informação']
    ],     
    [
     r'jornada Stone é por onde eu faço inscrição para todas as vagas que vocês têm hoje ou existe outra plataforma?',
     ['Você pode fazer a sua inscrição através do jornada Stone ou através do LinkedIn,  que são as duas plataformas que mais utilizamos']
    ],     
    [
     r' conversei com o recrutador alguns dias e ele foi muito legal comigo. foi a melhor entrevista da minha vida e queria elogiar ele pelo excelente trabalho prestado!!!',
     [' Muito obrigado pelo reconhecimento ao colaborador!  poderia me falar o nome dele assim eu consigo repassar os parabéns Ou se você quiser fazer isso pessoalmente,  Fique à vontade para falar com o recrutador que fez a entrevista com você!']
    ],     
    [
     r'O que precisa para ser um recruta?  é preciso inteligência energia integridade?',
     [' para ser um recruta você precisa de inteligência energia integridade.']
    ],     
    [
     r'O Recruta é um programa de estágio?',
     [' não de estágio,  mas um programa de talentos!']
    ],     
    [
     r'O que significa o valor own it que vocês têm na Stone?',
     ['Own it Significa você ter o espírito de dono aqui dentro da companhia!']
    ],     
    [
     r'O que significa o valor the reason?',
     ['The reason Significa que o cliente é a nossa razão de existir']
    ],     
    [
     r'  Vocês tem algum tipo de biblioteca para que os colaboradores se aprimorem cada vez mais?',
     [' Nós temos a biblioteca Stone onde dando sugestões de leituras e temos algumas aulas resumo sobre alguns livros que fazem muito sentido para a companhia ']
    ],     
    [
     r'Vocês são empreendedores dentro da Stone?  como funciona isso para os colaboradores?',
     [' Aqui na Stone todos são empreendedores E você tem muita liberdade para empreender em qualquer assunto dentro da companhia']
    ],     
    [
     r'A etapa que eu mais gostei do processo seletivo foi a dinâmica de grupos onde todos os candidatos se conheceram e puderam trocar entre si experiências?',
     [' Que legal que você gostou da dinâmica de grupos.  é uma experiência realmente incrível tanto para nós recrutadores quanto para os candidatos']
    ],     
    [
     r'Gostaria de tirar dúvidas a respeito da companhia e de uma  vaga que estou inscrito?',
     ['Olá Fique à vontade para tirar dúvidas a respeito da companhia através deste e-mail a qual você escreve,  e sobre a vaga também']
    ],     
    [
     r'Queria saber se a vaga Que Me inscrevi número 999887  ainda está aberta ou se ela já fechou na semana passada.  poderia me informar?',
     [' a vaga 999887  está fechada!  obrigado por perguntar e boa sorte no seu processo seletivo']
    ],     
    [
     r'Queria saber se para fazer os testes da mindsight  é necessário um computador ou eu posso fazer através do meu tablet ou smartphone?',
     [' você pode fazer através do tablet ou smartphone sim não existe nenhum tipo de problema.']
    ],     
    [
     r'Qual a chance dessa vaga sair do ar até na semana que vem?',
     [' a chance é mínima pode-se escrever com tranquilidade que você estará dentro do processo.']
    ],     
    [
     r'No dia 20/10  fiz a minha inscrição para a vaga de analista gostaria de saber se ela foi computada!',
     [' no dia 20/10  Recebemos a sua inscrição sim pode ficar tranquilo!']
    ],     
    [
     r'Qual a idade  máxima para entrar na Stone?',
     [' Olá tudo bem candidato nós não temos uma idade máxima para trabalhar aqui!não se preocupe com isso!']
    ],     
    [
     r'Vocês darão feedback sobre a vaga Que foi publicada na semana passada ou eu não saberei o meu resultado?',
     [' Olá tudo bem bom dia nós Sempre damos feedback para todas as vagas que publicamos então fica ligado no seu e-mail que você receber a ele por lá!']
    ],     
    [
     r'Quanto tempo dura a chamada de video que você marcou hoje á tarde comigo?',
     ['A nossa chamada de vídeo no será aproximadamente 45 minutos trataremos de assuntos técnicos  e aspectos gerais sobre a sua trajetória.Estamos bem animados para te conhecer melhor!']
    ],     
    [
     r'Olá boa tarde eu posso fazer o case da forma que eu melhor entender ou tem algum tipo de padrão que eu devo seguir?',
     [' O seu Case é exatamente para nós entendermos qual a sua forma de raciocínio e a sua estrutura de pensamento então você pode fazer da forma que melhor entender e apresentar para nós no dia que marcamos contigo!']
    ],     
     [
     r'ok,obrigado',
     ['De nada,agradecemos pelo seu contato,qualquer outra dúvida pode nos constatar']
    ],     
    [
     r'ok',
     ['De nada,agradecemos pelo seu contato,qualquer outra dúvida pode nos constatar!']
    ],
       [
     r'Ola',
     ['Oi,digite a sua duvida por gentileza']
    ],  
      [
     r'Quero falar com um atendente',
     ['Ok,StonBot agradece seu contato e logo estarei redirecionando para um de nossos atendentes!']
    ]
]

# %%
print('Olá,eu sou o Stonbot! Como posso ajudar?')
chat = Chat(pares, reflections_pt)
chat.converse()
# Out:
# Olá,eu sou o Stonbot! Como posso ajudar?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-d5304b31091e> in <module>
#       1 print('Olá,eu sou o Stonbot! Como posso ajudar?')
#       2 chat = Chat(pares, reflections_pt)
# ----> 3 chat.converse()
#
# /usr/local/lib/python3.7/dist-packages/nltk/chat/util.py in converse(self, quit)
#     116             user_input = quit
#     117             try:
# --> 118                 user_input = input(">")
#     119             except EOFError:
#     120                 print(user_input)
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# ...
